# %% [markdown]
# <a href="https://colab.research.google.com/github/PedireddiSiriSatya/FMML_COURSE_ASSISGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-07 08:08:10--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   142MB/s    in 0.5s
#
# 2023-05-07 08:08:11 (142 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 9103    1210.3926v2  The majority of online reviews consist of plai...    cs
# 11068   1312.7024v1  This paper introduces a novel model-based clus...  stat
# 27189  1702.07059v1  Mandible bone segmentation from computed tomog...    cs
# 20851  1703.09923v1  Self-paced learning (SPL) is a new methodology...    cs
# 1662   1709.08624v2  Automatically generating coherent and semantic...    cs
# ...             ...                                                ...   ...
# 9718   1711.08413v2  Effective utilization of photovoltaic (PV) pla...    cs
# 21825   1212.4562v1  We apply information-based complexity analysis...  stat
# 24173  1612.09161v2  Real-world image recognition systems need to r...    cs
# 4411   1706.02257v1  Advanced driver assistance systems (ADAS) can ...  stat
# 12725  1509.06113v3  Reinforcement learning provides a powerful and...    cs
#
#                                                    title  year  \
# 9103   Learning Attitudes and Attributes from Multi-A...  2012
# 11068  Model-based clustering with Hidden Markov Mode...  2013
# 27189  Robust and fully automated segmentation of man...  2017
# 20851  On Convergence Property of Implicit Self-paced...  2017
# 1662   Long Text Generation via Adversarial Training ...  2017
# ...                                                  ...   ...
# 9718   SolarisNet: A Deep Regression Network for Sola...  2017
# 21825  A complexity analysis of statistical learning ...  2012
# 24173              Learning Visual N-Grams from Web Data  2016
# 4411   Driver Action Prediction Using Deep (Bidirecti...  2017
# 12725  Deep Spatial Autoencoders for Visuomotor Learning  2015
#
#                                                 keywords
# 9103   [dimensions, understanding, contribute, unders...
# 11068  [introduces, clustering, clustering, polynomia...
# 27189  [segmentation, tomography, challenging, mandib...
# 20851  [methodology, simulates, principle, humansanim...
# 1662   [automatically, generating, semantically, mean...
# ...                                                  ...
# 9718   [effective, utilization, photovoltaic, variabi...
# 21825  [information, complexity, algorithms, comprehe...
# 24173  [recognition, recognize, thousands, constitute...
# 4411   [assistance, significantly, effective, predict...
# 12725  [reinforcement, framework, automated, acquisit...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 9103     [dimensions, understanding, contribute, unders...
# 11068    [introduces, clustering, clustering, polynomia...
# 27189    [segmentation, tomography, challenging, mandib...
# 20851    [methodology, simulates, principle, humansanim...
# 1662     [automatically, generating, semantically, mean...
#                                ...
# 22679    [describes, structuring, constructing, classif...
# 18601    [development, representation, reasoning, termi...
# 2205     [introduces, reinforcement, environment, speci...
# 21717    [strategic, advantages, configuration, nologic...
# 13560    [hierarchical, organization, recursive, compos...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8797 words.
# Out of those 4611 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="dc114cc3-acb8-4999-b93a-63c62e1da79c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc114cc3-acb8-4999-b93a-63c62e1da79c")) {                    Plotly.newPlot(                        "dc114cc3-acb8-4999-b93a-63c62e1da79c",                        [{"x":["attitudes","prediction","introduce","presumably","consisting","preferences","understanding","sentiment","automatically","particular","approaches","attributes","impression","sentences","summarize","disentangle","individual","understand","introducing","contribute","evaluation","indicative","recommend","dimensions","application","comparisons","successively","evaluated","diagnosis","introduces","regressions","algorithm","clustering","maximization","polynomial","expectation","including","likelihood","effectiveness","estimation","simulated","demonstrate","regression","performed","parameter","dedicated","underlying","activates","challenging","structural","intersection","segmentation","automated","operating","irregularities","addresses","detection","artifacts","challenges","proposing","connections","complementary","extremely","difficult","delineation","similarity","remaining","framework","specifically","experiments","tomography","recognition","furthermore","recognized","paradigms","principle","theoretical","converges","simulates","objective","convergence","robustness","empirically","relationship","conditions","effective","interpretations","especially","methodology","intrinsic","gradually","theoretically","captioning","generative","meaningful","combining","scenarios","translation","reinforcement","generator","semantically","intermediate","extensive","adversarial","implicitly","generating","structure","interaction","applications","performance","generation","generated","informative","additional","information","discriminative","promising","available","synthetic","structures","incorporates","supervision","importantly","extracted","presenting","maximizing","discriminant","functional","parameters","classification","alternative","variations","imperfect","outperforms","drastically","unconstrained","photographs","landmarks","processing","detections","successful","refinement","techniques","initialization","projection","morphable","correspondences","visibility","expressions","renderings","estimating","minimalistic","alignment","occlusions","implement","selection","discussed","different","conjectured","formulated","compatible","fingerprints","brazilian","statistical","procedure","literature","maximizer","retrieval","conjectures","identical","simulation","according","retrieved","comparing","contribution","linguistic","criterion","constituted","portuguese","consistency","previously","introduction","improvements","similarities","significantly","technique","significant","kernelized","sensitive","applicable","constructing","optimizing","efficiently","representation","variational","computational","subspaces","extraction","conventional","classifiers"],"y":[4,231,337,2,44,40,164,53,187,301,452,67,5,55,11,4,110,66,51,34,238,3,5,42,223,28,4,145,51,76,0,811,152,25,66,26,232,67,192,216,65,590,108,132,130,19,103,0,270,58,14,216,89,20,2,59,338,27,122,27,44,36,53,148,3,148,22,562,166,611,19,346,151,16,16,58,158,32,4,160,111,105,79,64,145,252,16,119,70,38,15,44,19,121,52,91,95,100,116,29,35,28,166,96,31,89,335,89,413,872,126,182,36,117,668,105,122,287,141,124,43,81,33,124,14,26,19,40,254,470,126,87,6,269,11,28,12,18,296,17,72,28,388,33,40,4,21,10,39,2,69,3,48,22,64,170,61,738,6,39,15,3,2,145,116,112,1,112,3,23,82,112,11,78,63,65,46,1,5,60,97,33,120,41,242,261,226,6,61,56,31,46,155,351,50,286,20,146,106,125],"type":"bar"},{"x":["attitudes","prediction","introduce","presumably","consisting","preferences","understanding", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4611,), (4611, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>SegNet</span> <span style=''>A</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.6075156576200418);'>Convolutional</span> <span style=''>Encoder</span> <span style=''>Decoder</span> <span style='background-color:rgba(0, 255, 0, 0.590778097982709);'>Architecture</span> <span style=''>for</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.7075098814229249);'>Segmentation</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>deep</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.6075156576200418);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.590778097982709);'>architecture</span> <span style=''>for</span> <span style=''>semantic</span> <span style=''>pixel</span> <span style=''>wise</span> <span style='background-color:rgba(0, 255, 0, 0.7075098814229249);'>segmentation</span> <span style=''>termed</span> <span style=''>SegNet</span> <span style=''>This</span> <span style=''>core</span> <span style='background-color:rgba(0, 255, 0, 0.5135135135135136);'>trainable</span> <span style='background-color:rgba(0, 255, 0, 0.7075098814229249);'>segmentation</span> <span style=''>engine</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>an</span> <span style=''>encoder</span> <span style=''>network</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>decoder</span> <span style=''>network</span> <span style=''>followed</span> <span style=''>by</span> <span style=''>a</span> <span style=''>pixel</span> <span style=''>wise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>layer</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.590778097982709);'>architecture</span> <span style=''>of</span> <span style=''>the</span> <span style=''>encoder</span> <span style=''>network</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333335);'>topologically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identical</span> <span style=''>to</span> <span style=''>the</span> <span style=''>13</span> <span style='background-color:rgba(0, 255, 0, 0.6075156576200418);'>convolutional</span> <span style=''>layers</span> <span style=''>in</span> <span style=''>the</span> <span style=''>VGG16</span> <span style=''>network</span> <span style=''>The</span> <span style=''>role</span> <span style=''>of</span> <span style=''>the</span> <span style=''>decoder</span> <span style=''>network</span> <span style=''>is</span> <span style=''>to</span> <span style=''>map</span> <span style=''>the</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.5853658536585367);'>resolution</span> <span style=''>encoder</span> <span style=''>feature</span> <span style=''>maps</span> <span style=''>to</span> <span style=''>full</span> <span style=''>input</span> <span style='background-color:rgba(0, 255, 0, 0.5853658536585367);'>resolution</span> <span style=''>feature</span> <span style=''>maps</span> <span style=''>for</span> <span style=''>pixel</span> <span style=''>wise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>The</span> <span style=''>novelty</span> <span style=''>of</span> <span style=''>SegNet</span> <span style=''>lies</span> <span style=''>is</span> <span style=''>in</span> <span style=''>the</span> <span style=''>manner</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style=''>decoder</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>upsamples</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Communication</span> <span style=''>Avoiding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>Methods</span> <span style=''>for</span> <span style=''>Massive</span> <span style=''>Scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structure</span> <span style=''>Learning</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Undirected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compactly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>large</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpreting</span> <span style=''>complex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scientific</span> <span style=''>data</span> <span style=''>Some</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>may</span> <span style=''>run</span> <span style=''>to</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>terabytes</span> <span style=''>and</span> <span style=''>current</span> <span style=''>methods</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style=''>in</span> <span style=''>both</span> <span style=''>memory</span> <span style=''>size</span> <span style=''>and</span> <span style=''>running</span> <span style=''>time</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>HP</span> <span style=''>CONCORD</span> <span style=''>a</span> <span style=''>highly</span> <span style=''>scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>inverse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrix</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>pseudolikelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>Our</span> <span style=''>parallel</span> <span style=''>proximal</span> <span style=''>gradient</span> <span style=''>method</span> <span style=''>runs</span> <span style=''>across</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>node</span> <span style=''>cluster</span> <span style=''>and</span> <span style=''>achieves</span> <span style=''>parallel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scalability</span> <span style=''>using</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>communication</span> <span style=''>avoiding</span> <span style=''>linear</span> <span style=''>algebra</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style='background-color:rgba(0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Complexity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Weighted</span> <span style=''>Fused</span> <span style=''>Lasso</span> <br/><br/><span style=''>The</span> <span style=''>solution</span> <span style=''>path</span> <span style=''>of</span> <span style=''>the</span> <span style=''>1D</span> <span style=''>fused</span> <span style=''>lasso</span> <span style=''>for</span> <span style=''>an</span> <span style=''>n</span> <span style='background-color:rgba(255, 0, 0, 0.32737030411449014);'>dimensional</span> <span style=''>input</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>piecewise</span> <span style=''>linear</span> <span style=''>with</span> <span style=''>mathcalO(n)</span> <span style=''>segments</span> <span style=''>(Hoefling</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2010</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333332);'>Tibshirani</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2011)</span> <span style=''>However</span> <span style=''>existing</span> <span style=''>proofs</span> <span style=''>of</span> <span style=''>this</span> <span style=''>bound</span> <span style=''>do</span> <span style=''>not</span> <span style=''>hold</span> <span style=''>for</span> <span style=''>the</span> <span style=''>weighted</span> <span style=''>fused</span> <span style=''>lasso</span> <span style=''>At</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>results</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalized</span> <span style=''>lasso</span> <span style=''>of</span> <span style=''>which</span> <span style=''>the</span> <span style=''>weighted</span> <span style=''>fused</span> <span style=''>lasso</span> <span style=''>is</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>allow</span> <span style=''>Omega(3n)</span> <span style=''>segments</span> <span style=''>(Mairal</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2012)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>segments</span> <span style=''>in</span> <span style=''>the</span> <span style=''>solution</span> <span style=''>path</span> <span style=''>of</span> <span style=''>the</span> <span style=''>weighted</span> <span style=''>fused</span> <span style=''>lasso</span> <span style=''>is</span> <span style=''>mathcalO(n3)</span> <span style=''>and</span> <span style=''>for</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instances</span> <span style=''>Omega(n2)</span> <span style=''>We</span> <span style=''>also</span> <span style=''>give</span> <span style=''>a</span> <span style=''>new</span> <span style=''>very</span> <span style=''>simple</span> <span style=''>proof</span> <span style=''>of</span> <span style=''>the</span> <span style=''>mathcalO(n)</span> <span style=''>bound</span> <span style=''>for</span> <span style=''>the</span> <span style=''>fused</span> <span style=''>lasso</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>InterpNET</span> <span style=''>Neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Introspection</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Interpretable</span> <span style=''>Deep</span> <span style=''>Learning</span> <br/><br/><span style=''>Humans</span> <span style=''>are</span> <span style=''>able</span> <span style=''>to</span> <span style=''>explain</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasoning</span> <span style=''>On</span> <span style=''>the</span> <span style=''>contrary</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>not</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>attempts</span> <span style=''>to</span> <span style=''>bridge</span> <span style=''>this</span> <span style=''>gap</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introducing</span> <span style=''>a</span> <span style=''>new</span> <span style=''>way</span> <span style=''>to</span> <span style=''>design</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>inspired</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>physiological</span> <span style=''>evidence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>human</span> <span style=''>visual</span> <span style=''>systems</span> <span style=''>inner</span> <span style=''>workings</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>design</span> <span style=''>paradigm</span> <span style=''>termed</span> <span style=''>InterpNET</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>combined</span> <span style=''>with</span> <span style=''>any</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>to</span> <span style=''>generate</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanations</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifications</span> <span style=''>The</span> <span style=''>success</span> <span style=''>of</span> <span style=''>the</span> <span style=''>module</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style=''>networks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasoning</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>in</span> <span style=''>its</span> <span style=''>internal</span> <span style=''>layer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activations</span> <span style=''>While</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principle</span> <span style=''>InterpNET</span> <span style=''>could</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>any</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.11808776311095255)
# 	representation (0.12522297538351765)
# 	processing (0.10560114163396361)
# 	information (0.23831608990367464)
# 	segmentation (0.07706029254370317)
# 	architecture (0.0984659293613985)
# 	detection (0.12058508740635034)
# 	different (0.2632893328576525)
# 	recognition (0.12343917231537638)
# 	convolutional (0.13735283624687836)
#
# Some Statistics words are:
# 	theoretical (0.14772158237356034)
# 	variables (0.13920881321982975)
# 	statistical (0.1517275913870806)
# 	stochastic (0.14521782674011016)
# 	estimation (0.18227341011517276)
# 	algorithm (0.39659489233850775)
# 	distribution (0.1842764146219329)
# 	dimensional (0.18577866800200302)
# 	inference (0.20380570856284427)
# 	regression (0.18527791687531298)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="527ed24f-429d-4167-89c2-73971d8c1a70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("527ed24f-429d-4167-89c2-73971d8c1a70")) {                    Plotly.newPlot(                        "527ed24f-429d-4167-89c2-73971d8c1a70",                        [{"x":["attitudes","prediction","introduce","presumably","consisting","preferences","understanding","sentiment","automatically","particular","approaches","attributes","impression","sentences","summarize","disentangle","individual","understand","introducing","contribute","evaluation","indicative","recommend","dimensions","application","comparisons","successively","evaluated","diagnosis","introduces","regressions","algorithm","clustering","maximization","polynomial","expectation","including","likelihood","effectiveness","estimation","simulated","demonstrate","regression","performed","parameter","dedicated","underlying","activates","challenging","structural","intersection","segmentation","automated","operating","irregularities","addresses","detection","artifacts","challenges","proposing","connections","complementary","extremely","difficult","delineation","similarity","remaining","framework","specifically","experiments","tomography","recognition","furthermore","recognized","paradigms","principle","theoretical","converges","simulates","objective","convergence","robustness","empirically","relationship","conditions","effective","interpretations","especially","methodology","intrinsic","gradually","theoretically","captioning","generative","meaningful","combining","scenarios","translation","reinforcement","generator","semantically","intermediate","extensive","adversarial","implicitly","generating","structure","interaction","applications","performance","generation","generated","informative","additional","information","discriminative","promising","available","synthetic","structures","incorporates","supervision","importantly","extracted","presenting","maximizing","discriminant","functional","parameters","classification","alternative","variations","imperfect","outperforms","drastically","unconstrained","photographs","landmarks","processing","detections","successful","refinement","techniques","initialization","projection","morphable","correspondences","visibility","expressions","renderings","estimating","minimalistic","alignment","occlusions","implement","selection","discussed","different","conjectured","formulated","compatible","fingerprints","brazilian","statistical","procedure","literature","maximizer","retrieval","conjectures","identical","simulation","according","retrieved","comparing","contribution","linguistic","criterion","constituted","portuguese","consistency","previously","introduction","improvements","similarities","significantly","technique","significant","kernelized","sensitive","applicable","constructing","optimizing","efficiently","representation","variational","computational","subspaces","extraction","conventional","classifiers","efficient","biomedical","computing","nonlinear","corresponding","approximate","depending","resemblance","processed","practitioners","consistent","approximating","corresponds","empirical","projections","perspective","essentially","approximates","algorithms","conducted","compression","resolution","compressed","convolutional","reduction","concerned","intuitive","nevertheless","complicated","distortion","trainable","subproblems","impressive","sequential","knowledge","enhancement","independent","computationally","presented","distribution","structured","dimension","quantization","simulator","developing","associated","optimized","transferring","limitation","architecture","projecting","pretrained","remarkable","supervised","complexity","extensively","classifier","multila ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	regressions
# 	activates
# 	clairvoyant
# 	stepsizes
# 	refitting
# 	submodels
# 	uncontaminated
# 	preselected
# 	exogenous
# 	reparametrizations
# 	reparameterizations
# 	temperatures
# 	chemicals
# 	unattainable
# 	gracefully
# 	blackwellized
# 	integrative
# 	propensity
# 	solvation
# 	cheminformatics
# Some words which never appear in Statistics papers:
# 	irregularities
# 	morphable
# 	occlusions
# 	downloading
# 	photometric
# 	dempsters
# 	concretely
# 	localizing
# 	patterned
# 	intellectual
# 	evaluator
# 	formalisms
# 	populated
# 	gastrointestinal
# 	functionality
# 	endoscopy
# 	undertaken
# 	paragraphs
# 	referenced
# 	curriculum

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.063631628932937e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77
